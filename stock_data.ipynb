# %% [markdown]
# ##***Making Financial Statements More Accessible***

# %%
# %reset -f

# %%
! pip install yfinance
! pip install openai
! pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 88.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.8 MB/s eta 0:00:00
# ...

# %%
# all required imports

import pandas as pd
import numpy as np
import datetime
import time
import openai
import requests
import os
import streamlit as st
import pandas as pd
import yfinance as yf
import requests
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install python-dotenv

# %%
import os

from dotenv import load_dotenv
load_dotenv('/content/drive/MyDrive/my_secrets.env')

API_key = os.getenv('API_key')

# %%
# get all the symbols

sp_500 = pd.read_csv('/content/drive/MyDrive/sp500_companies.csv')
tkrs = sp_500['Symbol']
ticker_list = tkrs.tolist()
ticker_list
# Out:
# ['AAPL',
#  'NVDA',
#  'MSFT',
#  'AMZN',
#  'GOOGL',
#  'GOOG',
#  'META',
#  'TSLA',
#  'AVGO',
#  'BRK-B',
#  'WMT',
#  'LLY',
#  'JPM',
#  'V',
#  'MA',
#  'ORCL',
#  'XOM',
#  'UNH',
#  'COST',
#  'PG',
#  'HD',
#  'NFLX',
#  'JNJ',
#  'BAC',
#  'CRM',
#  'ABBV',
#  'KO',
#  'TMUS',
#  'CVX',
#  'MRK',
#  'WFC',
#  'CSCO',
#  'ACN',
#  'NOW',
#  'AXP',
#  'MCD',
#  'PEP',
#  'BX',
#  'IBM',
#  'DIS',
#  'LIN',
#  'TMO',
#  'MS',
#  'ABT',
#  'ADBE',
#  'AMD',
#  'PM',
#  'ISRG',
#  'PLTR',
#  'GE',
#  'INTU',
#  'GS',
#  'CAT',
#  'TXN',
#  'QCOM',
#  'VZ',
#  'BKNG',
#  'DHR',
#  'T',
#  'BLK',
#  'RTX',
#  'SPGI',
#  'PFE',
#  'HON',
#  'NEE',
#  'CMCSA',
#  'ANET',
#  'AMGN',
#  'PGR',
#  'LOW',
#  'SYK',
#  'UNP',
#  'TJX',
#  'KKR',
#  'SCHW',
#  'ETN',
#  'AMAT',
#  'BA',
#  'BSX',
#  'C',
#  'UBER',
#  'COP',
#  'PANW',
#  'ADP',
#  'DE',
#  'FI',
#  'BMY',
#  'LMT',
#  'GILD',
#  'NKE',
#  'CB',
#  'UPS',
#  'ADI',
#  'MMC',
#  'MDT',
#  'VRTX',
#  'MU',
#  'SBUX',
# ...

# %%
stocks_dict = {}

# use appropriate rate-limiting to get all data
for tkr in ticker_list:
    time.sleep(2)
    url = f"https://finnhub.io/api/v1/quote?symbol={tkr}&token={API_key}"
    resp = requests.get(url)
    data = resp.json()
    stocks_dict[tkr] = data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8fa6fb86390f> in <cell line: 0>()
#       3 # use appropriate rate-limiting to get all data
#       4 for tkr in ticker_list:
# ----> 5     time.sleep(2)
#       6     url = f"https://finnhub.io/api/v1/quote?symbol={tkr}&token={API_key}"
#       7     resp = requests.get(url)
#
# KeyboardInterrupt:

# %%
stocks_dict
# Out:
# {'AAPL': {'c': 211.33,
#   'd': -1,
#   'dp': -0.471,
#   'h': 212.96,
#   'l': 209.54,
#   'o': 210.95,
#   'pc': 212.33,
#   't': 1747339200},
#  'NVDA': {'c': 134.83,
#   'd': -0.51,
#   'dp': -0.3768,
#   'h': 136.3,
#   'l': 132.66,
#   'o': 134.295,
#   'pc': 135.34,
#   't': 1747339200}}

# %%
from datetime import datetime
timestamp_str = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"stocks_data_{timestamp_str}.json"

# %% [markdown]
# c - current price
#
# d - change
#
# dp - percent change
#
# h - high price
#
# l - low price
#
# o - open price
#
# p - previous close price
#
# t - timestamp

# %%
stocks_data_with_timestamp = {
    "timestamp": datetime.now().isoformat(),
    "data": stocks_dict
}

with open(filename, "w") as f:
    json.dump(stocks_data_with_timestamp, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4fbc18fb23a8> in <cell line: 0>()
#       1 stocks_data_with_timestamp = {
#       2     "timestamp": datetime.now().isoformat(),
# ----> 3     "data": stocks_dict
#       4 }
#       5
#
# NameError: name 'stocks_dict' is not defined

# %%
# !pip install elasticsearch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.5/905.5 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.6 MB/s eta 0:00:00
# ...

# %%
elastic_username = "elastic"
elastic_password = "CHVE8I8eSrTm51ugrCnPay9a"
endpoint = "https://a6f3f2a9bd694e308e3da03571231683.us-central1.gcp.cloud.es.io"

# %%
import sys
# !{sys.executable} -m pip install haystack-ai
# !{sys.executable} -m pip install elasticsearch-haystack
# !{sys.executable} -m pip elasticsearch-haystack
# !{sys.executable} -m pip install huggingface_hub
# !{sys.executable} -m pip  install "huggingface_hub>=0.27.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.0/494.0 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.3/906.3 kB 22.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.3 MB/s eta 0:00:00
# ...
# ERROR: unknown command "elasticsearch-haystack"
# ...

# %%
import os
from haystack import Pipeline
from haystack_integrations.document_stores.elasticsearch import ElasticsearchDocumentStore
from haystack_integrations.components.retrievers.elasticsearch import ElasticsearchBM25Retriever
from haystack.components.builders.prompt_builder import PromptBuilder
from haystack.components.generators import HuggingFaceAPIGenerator
from haystack.components.converters import PyPDFToDocument
from haystack.components.writers import DocumentWriter
from haystack.components.preprocessors import DocumentSplitter
from haystack.utils import Secret
from elasticsearch import Elasticsearch, NotFoundError
import huggingface_hub

# %%
client = Elasticsearch(hosts="https://a6f3f2a9bd694e308e3da03571231683.us-central1.gcp.cloud.es.io", basic_auth=("elastic", elastic_password))

# %%
index_name = "stocks_data"

try:
    client.indices.delete(index=index_name)
except NotFoundError:
    print("Index doesn't exist!")
client.indices.create(index=index_name)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'stocks_data'})

# %%
document_store = ElasticsearchDocumentStore( # NOTE: adjust credentials
    hosts="https://a6f3f2a9bd694e308e3da03571231683.us-central1.gcp.cloud.es.io",
    basic_auth=("elastic", elastic_password),
    index=index_name
)

# %%
! pip install pypdf

# %%
import os
os.kill(os.getpid(), 9)

# %%
# test with one company for now

import pypdf

file_path = "/content/drive/MyDrive/FY24_Q4_Consolidated_Financial_Statements.pdf"

index_pipeline = Pipeline()
index_pipeline.add_component("converter", PyPDFToDocument())
index_pipeline.add_component("splitter", DocumentSplitter(split_by="word", split_length=150))
index_pipeline.add_component("writer", DocumentWriter(document_store))
index_pipeline.connect("converter", "splitter")
index_pipeline.connect("splitter", "writer")



index_pipeline.run({"converter": {"sources": [file_path]}})
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 7 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 15 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 30 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 33 0 (offset 0)
# {'writer': {'documents_written': 14}}

# %% [markdown]
# (AI-generated information)
#
# column names in num.txt:
#
# 1) tag: Financial metric identifier in XBRL taxonomy (e.g.,
#    RevenueFromContractWithCustomer)
#
# 2) version: Which taxonomy the tag belongs to, e.g. us-gaap/2024 or ifrs/2024
#
# 3) ddate: Date for which the data point is valid (usually a fiscal end date,
#    like 20241231)
#
# 4) qtrs: Number of fiscal quarters this data point covers (0 = point-in-time, 4
#    = annual)
#
# 5) uom: Unit of measure (e.g., USD, CAD)
#
# 6) segments: Optional breakdown info (e.g., BusinessSegments=AllOtherSegments)
#
# 7) coreg: Co-registrant identifier (used in joint filings)
#
# 8) value: The actual numeric value being reported
#
# 9) footnote: Explanatory notes attached to the value (if any)

# %%
# !pip install dotenv

# %%
import os
from dotenv import load_dotenv

load_dotenv('/content/drive/MyDrive/my_secrets.env')
huggingface_token = os.getenv('HF_token')


from huggingface_hub import login
login(token=huggingface_token)

# %%
retriever = ElasticsearchBM25Retriever(document_store=document_store)
generator = HuggingFaceAPIGenerator(
    api_type="serverless_inference_api",
    api_params={"model": "microsoft/Phi-3.5-mini-instruct", "max_new_tokens": 200 })
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
#
#
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.

# %%
template = """
<|system|>
You are a helpful assistant.<|end|>
<|user|>
Given the following information, answer the question.

Context:
{% for document in documents %}
    {{ document.content }}
{% endfor %}

Question: {{ query }}?<|end|>
<|assistant|>"""

# %%
rag_pipeline = Pipeline()
rag_pipeline.add_component("retriever", retriever)
rag_pipeline.add_component("prompt_builder", PromptBuilder(template=template))
rag_pipeline.add_component("llm", generator)
rag_pipeline.connect("retriever", "prompt_builder.documents")
rag_pipeline.connect("prompt_builder", "llm")
# Out:
# WARNING:haystack.components.builders.prompt_builder:PromptBuilder has 2 prompt variables, but `required_variables` is not set. By default, all prompt variables are treated as optional, which may lead to unintended behavior in multi-branch pipelines. To avoid unexpected execution, ensure that variables intended to be required are explicitly set in `required_variables`.
# ...
# 🚅 Components
#   - retriever: ElasticsearchBM25Retriever
#   - prompt_builder: PromptBuilder
#   - llm: HuggingFaceAPIGenerator
# 🛤️ Connections
#   - retriever.documents -> prompt_builder.documents (List[Document])
#   - prompt_builder.prompt -> llm.prompt (str)

# %%
def generate(query):
    assert rag_pipeline is not None
    res = rag_pipeline.run({
        "prompt_builder": {"query": query},
        "retriever": {"query": query}
    })
    return res['llm']['replies'][0]

# %%
queries = [
    "Summarize Apple Inc.’s overall financial performance for the fiscal year ending September 28, 2024."
]

for query in queries:
    response = generate(query)
    print(f"Query: {query}\nResponse: {response}\n")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/inference/_client.py:2234: FutureWarning:
#
# `stop_sequences` is a deprecated argument for `text_generation` task and will be removed in version '0.28.0'. Use `stop` instead.
# Query: Summarize Apple Inc.’s overall financial performance for the fiscal year ending September 28, 2024.
# Response: Apple Inc.'s overall financial performance for the fiscal year ending September 28, 2024, showed growth and profitability across various segments:
#
# 1. Net Sales: Apple's net sales increased to $391.035 billion from $383.285 billion in the previous year, with significant growth in iPhone sales, Mac, iPad, Wearables, Home & Accessories, and Services.
#
# 2. Operating Income: The company's operating income rose to $93.736 billion, up from $96.995 billion in the previous year. This increase reflects the company's strong performance in its core business operations.
#
# ...

# %%
# use the json data to create heatmaps of different stocks

# %%
# !pip install streamlit

# %%
! pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.4/303.4 kB 6.5 MB/s eta 0:00:00
# ...

# %%
""" figure out how to load the history of all the tech stocks here """

file_path = "./content/drive/MyDrive/history"

# %%
""" replicate this in app.py """
import yfinance as yf
import plotly.express as pt

tickers = ["AAPL", "MSFT", "GOOGL", "AMZN", "META", "NVDA", "TSLA", "AMD", "CRM", "ADBE", "INTC", "ORCL"]
data = yf.download(tickers, start="2020-01-01", end="2024-12-31", group_by='ticker')
data = data.stack(level=0).reset_index()
appl_data = data[data['Ticker'] == 'AAPL']
# print(data.columns)

appl_data = data[data['Ticker'] == 'AAPL']
fig = pt.line(appl_data, x='Date', y='Close', title='AAPL Close Price')
fig.show()

data
# Out:
# [*********************100%***********************]  12 of 12 completed
# <ipython-input-37-0bbb46193e27>:7: FutureWarning:
#
# The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import pytz
from datetime import datetime
import requests
import time
from haystack import Pipeline
from haystack_integrations.document_stores.elasticsearch import ElasticsearchDocumentStore
from haystack_integrations.components.retrievers.elasticsearch import ElasticsearchBM25Retriever
from haystack.components.builders.prompt_builder import PromptBuilder
from haystack.components.generators import HuggingFaceAPIGenerator
from haystack.components.converters import PyPDFToDocument
from haystack.components.writers import DocumentWriter
from haystack.components.preprocessors import DocumentSplitter
from elasticsearch import Elasticsearch, NotFoundError
from huggingface_hub import login
import tempfile
import os
from dotenv import load_dotenv
import yfinance as yf
import plotly.express as pt

load_dotenv('/content/drive/MyDrive/my_secrets.env')
elastic_password = os.getenv('elastic_password')
huggingface_token = os.getenv('HF_token')


st.set_page_config(layout="wide")
st.title("📈 Tech Stock Performance Dashboard")


# Elastic config
elastic_username = "elastic"
endpoint = "https://a6f3f2a9bd694e308e3da03571231683.us-central1.gcp.cloud.es.io"
index_name = "stocks_data"


client = Elasticsearch(hosts=endpoint, basic_auth=(elastic_username, elastic_password))


try:
    client.indices.delete(index=index_name)
except NotFoundError:
    pass


client.indices.create(index=index_name)

document_store = ElasticsearchDocumentStore(
    hosts=endpoint,
    basic_auth=(elastic_username, elastic_password),
    index=index_name
)


login(token=huggingface_token)
retriever = ElasticsearchBM25Retriever(document_store=document_store)
generator = HuggingFaceAPIGenerator(
    api_type="serverless_inference_api",
    api_params={"model": "microsoft/Phi-3.5-mini-instruct", "max_new_tokens": 200}
)


template = """
<|system|>
You are a helpful assistant.<|end|>
<|user|>
Given the following information, answer the question.

Context:
{% for document in documents %}
    {{ document.content }}
{% endfor %}

Question: {{ query }}?<|end|>
<|assistant|>"""


rag_pipeline = Pipeline()
rag_pipeline.add_component("retriever", retriever)
rag_pipeline.add_component("prompt_builder", PromptBuilder(template=template, required_variables=["documents", "query"]))
rag_pipeline.add_component("llm", generator)
rag_pipeline.connect("retriever", "prompt_builder.documents")
rag_pipeline.connect("prompt_builder", "llm")


def generate_summary_from_pdf(uploaded_file, query):
    with tempfile.NamedTemporaryFile(delete=False, suffix=".pdf") as tmp:
        tmp.write(uploaded_file.read())
        tmp_path = tmp.name

    index_pipeline = Pipeline()
    index_pipeline.add_component("converter", PyPDFToDocument())
    index_pipeline.add_component("splitter", DocumentSplitter(split_by="word", split_length=150))
    index_pipeline.add_component("writer", DocumentWriter(document_store))
    index_pipeline.connect("converter", "splitter")
    index_pipeline.connect("splitter", "writer")

    index_pipeline.run({"converter": {"sources": [tmp_path]}})

    result = rag_pipeline.run({
        "retriever": {"query": query},
        "prompt_builder": {"query": query}
    })

    return result["llm"]["replies"][0]



tech_tickers = ["AAPL", "MSFT", "GOOGL", "AMZN", "META", "NVDA", "TSLA", "AMD", "CRM", "ADBE", "INTC", "ORCL"]
API_KEY = os.getenv('API_key')
central = pytz.timezone("US/Central")

def fetch_stock_quote(ticker):
    time.sleep(1.5)
    url = f"https://finnhub.io/api/v1/quote?symbol={ticker}&token={API_KEY}"
    resp = requests.get(url)
    return resp.json()

col1, col2 = st.columns(2)

with col1:
    st.divider()
    st.subheader("📊 Stock Snapshot Viewer")
    tickers = ["Select a company: "] + tech_tickers
    selected = st.selectbox("Company:", tickers)

    if selected != "Select a company: ":
        quote = fetch_stock_quote(selected)
        change = quote["c"] - quote["o"]
        percent_change = (change / quote["o"]) * 100 if quote["o"] != 0 else 0

        ts = pd.to_datetime(quote["t"], unit="s").tz_localize("UTC").astimezone(central)
        formatted_time = ts.strftime("%Y-%m-%d %I:%M %p %Z")

        st.metric("Close Price", f"${quote['c']:.2f}", f"{change:+.2f} ({percent_change:+.2f}%)")

        st.write("**Details**")
        st.write({
            "Open": f"${quote['o']:.2f}",
            "High": f"${quote['h']:.2f}",
            "Low": f"${quote['l']:.2f}",
            "Close": f"${quote['c']:.2f}",
            "Volume": quote.get("v", "N/A"),
            "Timestamp": formatted_time
        })

with col2:
    if selected != "Select a company: ":
        selected_quote = fetch_stock_quote(selected)
        selected_close = selected_quote["c"]
        st.divider()
        st.subheader("📊 Compare with Peer Company")
        peer_candidates = [
            t for t in tech_tickers
            if t != selected and abs(fetch_stock_quote(t)["c"] - selected_close) / selected_close <= 0.05
        ]

        if peer_candidates:
            selected_peer = st.selectbox("Peer Company:", ["Select peer..."] + peer_candidates)

            if selected_peer != "Select peer...":
                peer_quote = fetch_stock_quote(selected_peer)
                peer_change = peer_quote["c"] - peer_quote["o"]
                peer_pct = (peer_change / peer_quote["o"]) * 100 if peer_quote["o"] != 0 else 0

                ts = pd.to_datetime(peer_quote["t"], unit="s").tz_localize("UTC").astimezone(central)
                formatted_time = ts.strftime("%Y-%m-%d %I:%M %p %Z")

                st.metric("Close Price", f"${peer_quote['c']:.2f}", f"{peer_change:+.2f} ({peer_pct:+.2f}%)")

                st.write("**Details**")
                st.write({
                    "Open": f"${peer_quote['o']:.2f}",
                    "High": f"${peer_quote['h']:.2f}",
                    "Low": f"${peer_quote['l']:.2f}",
                    "Close": f"${peer_quote['c']:.2f}",
                    "Volume": peer_quote.get("v", "N/A"),
                    "Timestamp": formatted_time
                })
        else:
            st.info("No peers found within 5% of the selected company's close price.")


st.divider()
if selected != "Select a company: ":
    st.subheader(f"📄 Upload {selected}'s Financial Report to Estimate Investment Timing")

    uploaded_file = st.file_uploader("Upload a PDF financial report", type=["pdf"])

    if uploaded_file:
        user_query = st.text_input(
            "Ask a question about the financial report:",
            value=f"Summarize {selected}'s overall financial performance."
        )

        if st.button("Generate Summary"):
            with st.spinner("Analyzing document..."):
              response = generate_summary_from_pdf(uploaded_file, user_query)
              st.success("Generated Summary:")
              st.write(response)

        else:
            st.info("Please select a company to upload its financial report.")


st.divider()
if selected != "Select a company: ":
    st.subheader(f"📈 Visualize {selected}'s Performance Over Time")
    start_date = st.date_input("Start Date", value=pd.to_datetime("2020-01-01"))
    end_date = st.date_input("End Date", value=pd.to_datetime("today"))
    data = yf.download(tech_tickers, start=start_date, end=end_date, group_by = 'ticker' )
    data = data.stack(level = 0).reset_index()
    plot_data = data[data['Ticker'] == selected]

    fig = pt.line(plot_data, x='Date', y='Close', title=f'{selected} Close Price From {start_date} to {end_date}')
    st.plotly_chart(fig, use_container_width=True)
# Out:
# Overwriting app.py

# %%
# !curl https://loca.lt/mytunnelpassword
# Out:
# 34.125.239.226

# %%
# !streamlit run /content/app.py & sleep 5 && yes | npx localtunnel --port 8501 --print-requests
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.239.226:8501
#
# ⠙⠹⠸⠼⠴your url is: https://silly-maps-switch.loca.lt
# Fri May 16 2025 20:57:40 GMT+0000 (Coordinated Universal Time) GET /
# Fri May 16 2025 20:57:40 GMT+0000 (Coordinated Universal Time) GET /static/media/SourceSansPro-Regular.DZLUzqI4.woff2
# Fri May 16 2025 20:57:40 GMT+0000 (Coordinated Universal Time) GET /static/media/SourceSansPro-SemiBold.sKQIyTMz.woff2
# Fri May 16 2025 20:57:40 GMT+0000 (Coordinated Universal Time) GET /static/media/SourceSansPro-Bold.-6c9oR8J.woff2
# Fri May 16 2025 20:57:40 GMT+0000 (Coordinated Universal Time) GET /static/css/index.DqDwtg6_.css
# Fri May 16 2025 20:57:40 GMT+0000 (Coordinated Universal Time) GET /static/js/index.C1z8KpLA.js
# Fri May 16 2025 20:57:41 GMT+0000 (Coordinated Universal Time) GET /_stcore/host-config
# ...

# %%
import os
from dotenv import load_dotenv

load_dotenv('/content/drive/MyDrive/my_secrets.env')
GITHUB_TOKEN = os.getenv("GIT_TOKEN")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-77-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# !git config --global user.email "asingh278@wisc.edu"
# !git config --global user.name "Arundhati Singh"

# %%
# !git remote set-url origin https://arundhatisingh17:$GITHUB_TOKEN@github.com/arundhatisingh17/TradeView.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/TradeView/
# !git add .
# !git commit -m "updated notebook"
# !git push --force
# Out:
# /content/drive/MyDrive/Colab Notebooks/TradeView
# [main d070bec] updated notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite stock_data.ipynb (94%)
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/arundhatisingh17/TradeView.git/'
